# %% [markdown]
# <a href="https://colab.research.google.com/github/kenmanongsong/CPE-103-OOP-1-A/blob/main/Long_Quiz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LONG QUIZ NO.1

# %%
from re import M
for i in range(3):
  class Student():
      def __init__(self, student_id, name, sex, weight, height):
        self.name = name
        self.student_id = student_id
        self.sex = sex
        self.weight = weight
        self.height = height

      def name(self):
          return self._name

      def student_id(self, _student_id):
          return self._student_id

      def sex(self):
          return self._sex

      def weight(self):
          return self._weight

      def height(self):
          return self._height

#PROMPT THE USER TO ENTER BASIC INFORMATIONS
  name = input("Enter your name: ")
  print("Name:", name)

  sex = input("Enter your sex: ")
  print("Sex:", sex)

  weight = input("Enter your weight: ")
  print("Weight:", weight)

  height = input("Enter your height: ")
  print("Height:", height)

  course = input("Enter your desired course (Available course: ECE101, IE102, CPE103, EE104): ")
  print("Course:", course)

  print()

#DISPLAYS THE PROVIDED INFORMATIONS
  print("-----STUDENT'S INFORMATION-----")
  print("Name:", name)
  print("Sex:", sex)
  print("Weight:", weight)
  print("Height:", height)
  print("Course:", course)

  if course == "ECE101":
    print("Your student id is: 20240001-E")
  elif course == "IE102":
    print("Your student id is: 20240002-E")
  elif course == "CPE103":
     print("Your student id is: 20240003-E")
  elif course == "EE104":
    print("Your student id is: 20240004-E")
  else:
    print("Not available course")
  print()

  class grades:
   def Midterm_Grade(self, MG, MEXAM):
      Midterm_Grade = MEXAM*.5 + MG*.5
      return Midterm_Grade

  def Final_Grade(self, FG, FEXAM):
      Final_Grade = FEXAM*.5 + FG*.5
      return Final_Grade
  print()

#PROMT THE USER TO ENTER HIS/HER MIDTERM GRADES THEN THE SYSTEM CALCULATES IT
  print("Enter your grades for midterm")
  MRECITATION = float(input("Enter your recitation grade: "))
  MQUIZ = float(input("Enter your quiz grade: "))
  MASSIGNMENT = float(input("Enter your assignment grade: "))
  MSEATWORK = float(input("Enter your seatwork grade: "))
  midtermgrade = MRECITATION*.5 + MQUIZ*.3 + MASSIGNMENT*.2 + MSEATWORK*.2
  MEXAM = float(input("Enter your midterm exam grade: "))
  MG = MEXAM*.5 + midtermgrade*.5
  print("Midterm grade is: ", "%.2f" % MG)
  print()

#PROMT THE USER TO ENTER HIS/HER FINAL GRADES THEN THE SYSTEM CALCULATES IT
  print("Enter your grades for final")
  FRECITATION = float(input("Enter your recitation grade: "))
  FQUIZ = float(input("Enter your quiz grade: "))
  FASSIGNMENT = float(input("Enter your assignment grade: "))
  FSEATWORK = float(input("Enter your seatwork grade: "))
  finalgrade = FRECITATION*.5 + FQUIZ*.3 + FASSIGNMENT*.2 + FSEATWORK*.2
  FEXAM = float(input("Enter your final exam grade: "))
  FG = FEXAM*.5 + finalgrade*.5
  print("Final grade is: ", "%.2f" % FG)
  print()

#DISPLAYES THE USER'S NAME AND HIS/HER MIDTERM AND FINAL GRADE
  print(name, "Your midterm grade is: ", "%.2f" % MG)
  print(name, "Your final grade is: ", "%.2f" % FG)

  def number_system(grade):
      if 99 <= grade <= 100:
        return 1.00
      elif 96 <= grade <= 98:
        return 1.25
      elif 93 <= grade <= 95:
        return 1.50
      elif 90 <= grade <= 92:
        return 1.75
      elif 87 <= grade <= 89:
        return 2.00
      elif 84 <= grade <= 86:
        return 2.25
      elif 81 <= grade <= 83:
        return 2.50
      elif 78 <= grade <= 80:
        return 2.75
      elif 75 <= grade <= 77:
        return 3.00
      else:
        return 5.00

#DISPLAYS HIS/HER AVERAGE GRADE
  print("Your final average: ", "%.2f" % number_system(FG))
  print()
  print("-----Next Student-----")
# Out:
# Enter your name: Ana
# Name: Ana
# Enter your sex: female
# Sex: female
# Enter your weight: 45kg
# Weight: 45kg
# Enter your height: 159cm
# Height: 159cm
# Enter your desired course (Available course: ECE101, IE102, CPE103, EE104): ECE101
# Course: ECE101
#
# -----STUDENT'S INFORMATION-----
# Name: Ana
# Sex: female
# Weight: 45kg
# Height: 159cm
# Course: ECE101
# Your student id is: 20240001-E
#
#
# Enter your grades for midterm
# Enter your recitation grade: 89
# Enter your quiz grade: 97
# Enter your assignment grade: 89
# Enter your seatwork grade: 93
# Enter your midterm exam grade: 68
# Midterm grade is:  89.00
#
# Enter your grades for final
# Enter your recitation grade: 83
# Enter your quiz grade: 78
# Enter your assignment grade: 73
# Enter your seatwork grade: 90
# Enter your final exam grade: 76
# Final grade is:  86.75
#
# Ana Your midterm grade is:  89.00
# Ana Your final grade is:  86.75
# Your final average:  5.00
#
# -----Next Student-----
# ...
